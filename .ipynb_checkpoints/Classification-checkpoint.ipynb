# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
features1 = pd.read_csv('Data/feature_vectors.csv',header = None,names=["sound.files","selec","duration","meanfreq","sd","freq.median","freq.Q25","freq.Q75","freq.IQR","time.median","time.Q25","time.Q75","time.IQR","skew","kurt","sp.ent","time.ent","entropy","sfm","meandom","mindom","maxdom","dfrange","modindx","startdom","enddom","dfslope","meanpeakf"
])
metadata1 = pd.read_csv('Data/metadata.csv', encoding = "ISO-8859-1")

# %%
def add_metadata(metadata, features):
    names = [x.split("-") for x in features['sound.files']]
    ids = [int(x[2].replace(".wav",'')) for x in names]
    ordered_metadata = pd.DataFrame()
    for i in ids:
        df = metadata[metadata.Recording_ID == i]
        ordered_metadata = ordered_metadata.append(df,ignore_index=True)
    X = ordered_metadata.join(features)
    good_rows = features.iloc[:,1:].apply(lambda x : not np.any(np.isnan(x)), axis = 1)
    mystery_rows = [x[0] == "Mystery" or x[0] == "Sonus" for x in names]
    #print([x[1] == "Soundscape" for x in names].count(True))
    return X[[a and not b for a,b in zip(good_rows,mystery_rows)]]

# %%
good_boi1 = add_metadata(metadata1,features1)

len(good_boi1)
# Out:
# 17564

# %%
len(good_boi1['Genus'].value_counts())
# Out:
# 139

# %%
len(good_boi1['English_name'].value_counts())
# Out:
# 288

# %%
with pd.option_context('display.max_rows',1000, 'display.max_columns', None):
    print(good_boi1['English_name'].value_counts())
# Out:
# Song Sparrow                     750
# Northern Cardinal                440
# Common Yellowthroat              386
# Western Meadowlark               341
# Black-headed Grosbeak            315
# Thick-billed Fox Sparrow         293
# Brown-crested Flycatcher         288
# Cassin's Sparrow                 273
# Brewer's Sparrow                 264
# Black-throated Sparrow           258
# Indigo Bunting                   240
# American Yellow Warbler          228
# Yellow-breasted Chat             216
# Eastern Meadowlark               213
# Field Sparrow                    189
# Lazuli Bunting                   187
# MacGillivray's Warbler           186
# Wilson's Warbler                 183
# Ovenbird                         175
# Dickcissel                       169
# Blue Grosbeak                    165
# American Redstart                164
# White-eyed Vireo                 163
# Scott's Oriole                   162
# Red-winged Blackbird             155
# Hooded Warbler                   154
# Loggerhead Shrike                153
# Swainson's Warbler               152
# Myrtle Warbler                   149
# Black-and-white Warbler          147
# Louisiana Waterthrush            144
# Chestnut-sided Warbler           143
# Lucy's Warbler                   142
# Black-throated Grey Warbler      139
# Bobolink                         139
# Painted Whitestart               137
# Nashville Warbler                137
# Bachman's Sparrow                136
# Northern Waterthrush             135
# Vesper Sparrow                   133
# Bullock's Oriole                 130
# Prairie Warbler                  130
# Rufous-winged Sparrow            128
# Black-chinned Sparrow            125
# Golden-winged Warbler            125
# Orchard Oriole                   123
# Magnolia Warbler                 121
# Hooded Oriole                    120
# Lark Sparrow                     119
# Baltimore Oriole                 115
# Chipping Sparrow                 114
# Western Tanager                  113
# Black-capped Chickadee           112
# Western Kingbird                 112
# Northern Parula                  111
# Orange-crowned Warbler           110
# Slate-colored Fox Sparrow        110
# Kentucky Warbler                 110
# Grace's Warbler                  110
# Mourning Warbler                 108
# Scarlet Tanager                  108
# Painted Bunting                  105
# Summer Tanager                   105
# Audubon's Warbler                104
# Ash-throated Flycatcher          103
# Rose-breasted Grosbeak           100
# Yellow-throated Warbler           98
# Cerulean Warbler                  96
# Anna's Hummingbird                95
# Black-throated Green Warbler      94
# Canada Warbler                    90
# Virginia's Warbler                88
# Acadian Flycatcher                88
# Eastern Phoebe                    87
# Botteri's Sparrow                 86
# Black-throated Blue Warbler       85
# Blackburnian Warbler              85
# Chuck-will's-widow                83
# Canyon Towhee                     80
# Mountain Chickadee                80
# Kirtland's Warbler                78
# Carolina Chickadee                78
# Blue-winged Warbler               77
# Red-faced Warbler                 75
# Cordilleran Flycatcher            73
# Prothonotary Warbler              73
# American Grey Flycatcher          70
# Boat-tailed Grackle               68
# Bell's Sparrow                    67
# Willow Flycatcher                 65
# Lincoln's Sparrow                 65
# Bay-breasted Warbler              65
# Eastern Whip-poor-will            65
# Mourning Dove                     64
# Alder Flycatcher                  63
# Tennessee Warbler                 60
# Hermit Warbler                    59
# Great-tailed Grackle              58
# Greater Pewee                     58
# Northern Bobwhite                 57
# Least Flycatcher                  56
# Common Grackle                    55
# Five-striped Sparrow              55
# Townsend's Warbler                54
# Vermilion Flycatcher              54
# Sage Grouse                       53
# American Dusky Flycatcher         53
# White-winged Dove                 52
# Pyrrhuloxia                       51
# Buff-breasted Flycatcher          51
# Pine Warbler                      51
# Cape May Warbler                  50
# Brown-headed Cowbird              50
# Yellow-headed Blackbird           49
# Western Wood Pewee                49
# American Tree Sparrow             49
# Rusty Blackbird                   49
# Blackpoll Warbler                 48
# Varied Bunting                    45
# Say's Phoebe                      44
# Cassin's Kingbird                 43
# Connecticut Warbler               42
# Laysan Albatross                  41
# Eastern Towhee                    40
# Black Phoebe                      40
# Common Poorwill                   40
# Brewer's Blackbird                39
# Abert's Towhee                    38
# Mountain Quail                    38
# Sagebrush Sparrow                 37
# Eastern Wood Pewee                36
# Great Crested Flycatcher          35
# Yellow-bellied Flycatcher         35
# Mexican Chickadee                 35
# Long-billed Dowitcher             34
# Willet                            34
# Hepatic Tanager                   33
# Rock Sandpiper                    33
# Northern Flicker                  32
# Scaled Quail                      32
# Blue-throated Mountaingem         32
# Western Sandpiper                 30
# American Bittern                  30
# Verdin                            30
# Barred Owl                        30
# Palm Warbler                      30
# Sooty Fox Sparrow                 30
# Elegant Trogon                    30
# Greater Prairie Chicken           29
# Northern Pygmy Owl                28
# Olive-sided Flycatcher            28
# Buff-collared Nightjar            28
# Great Horned Owl                  27
# American Woodcock                 26
# Colima Warbler                    26
# Northern Saw-whet Owl             25
# Dusky-capped Flycatcher           25
# California Quail                  24
# Sulphur-bellied Flycatcher        24
# Pacific-slope Flycatcher          23
# Horned Lark                       23
# Yellow-billed Cuckoo              23
# White-tipped Dove                 23
# Semipalmated Sandpiper            23
# Mexican Whip-poor-will            21
# Common Ground Dove                20
# Whiskered Screech Owl             20
# Plain Chachalaca                  19
# Greater Roadrunner                19
# Hammond's Flycatcher              18
# Olive Sparrow                     18
# Clay-colored Sparrow              18
# Zebra Dove                        18
# Virginia Rail                     17
# Tropical Parula                   17
# American Golden Plover            15
# Chestnut-backed Chickadee         15
# Great Kiskadee                    15
# Scissor-tailed Flycatcher         15
# Couch's Kingbird                  15
# Black-billed Cuckoo               15
# Tricolored Blackbird              15
# Northern Shrike                   15
# Flame-colored Tanager             15
# Flammulated Owl                   15
# Western Screech Owl               15
# Dunlin                            15
# Bristle-thighed Curlew            15
# White-crowned Pigeon              15
# Morelet's Seedeater               14
# Worm-eating Warbler               14
# Pacific Golden Plover             13
# Boreal Chickadee                  13
# Gambel's Quail                    13
# Red Phalarope                     12
# Golden-cheeked Warbler            11
# Forster's Tern                    10
# Audubon's Oriole                  10
# Grey Kingbird                     10
# Rufous-capped Warbler             10
# Inca Dove                         10
# Grey-crowned Yellowthroat         10
# Wild Turkey                       10
# Stilt Sandpiper                   10
# Sooty Grouse                      10
# Baird's Sandpiper                 10
# Clapper Rail                      10
# Eastern Screech Owl               10
# Pied-billed Grebe                 10
# Surfbird                          10
# Red-throated Loon                 10
# Red-breasted Merganser            10
# California Towhee                 10
# Rivoli's Hummingbird              10
# Polynesian Wattled Honeyeater     10
# Pauraque                          10
# Shiny Cowbird                     10
# Eurasian Collared Dove             9
# Gila Woodpecker                    9
# Pectoral Sandpiper                 9
# Killdeer                           8
# Eastern Kingbird                   8
# Altamira Oriole                    8
# Sharp-tailed Grouse                7
# Long-billed Curlew                 6
# Rock Ptarmigan                     6
# Pacific Loon                       6
# Harris's Hawk                      5
# Elf Owl                            5
# Band-tailed Pigeon                 5
# White-throated Swift               5
# Least Bittern                      5
# Greater Yellowlegs                 5
# Chukar Partridge                   5
# Laughing Gull                      5
# Northern Shoveler                  5
# Red-breasted Sapsucker             5
# Red-naped Sapsucker                5
# Limpkin                            5
# Mariana Fruit Dove                 5
# Wilson's Snipe                     5
# Thick-billed Kingbird              5
# Semipalmated Plover                5
# Vaux's Swift                       5
# Green Heron                        5
# Pileated Woodpecker                5
# Wilson's Plover                    5
# Western Grebe                      5
# Sora                               5
# Long-eared Owl                     5
# Grey Partridge                     5
# Costa's Hummingbird                5
# Boreal Owl                         5
# Downy Woodpecker                   5
# Clark's Grebe                      5
# Calliope Hummingbird               5
# Red-crested Cardinal               5
# Northern Beardless Tyrannulet      5
# Mallard                            5
# Great Blue Heron                   5
# Hairy Woodpecker                   5
# Spotted Owl                        5
# Berylline Hummingbird              5
# Red-necked Stint                   5
# Bar-tailed Godwit                  5
# Canada Goose                       5
# Marbled Godwit                     5
# Antillean Nighthawk                5
# Ferruginous Pygmy Owl              5
# Grey Hawk                          5
# Mountain Pygmy Owl                 5
# Rock Dove                          5
# Ruddy Duck                         5
# Black Rail                         5
# Common Pheasant                    4
# Violet-crowned Hummingbird         4
# Red Knot                           4
# Nutting's Flycatcher               4
# Chimney Swift                      4
# Nuttall's Woodpecker               4
# African Collared Dove              4
# Montezuma Quail                    3
# Scarlet Flycatcher                 3
# Lesser Yellowlegs                  3
# Glaucous Gull                      3
# White-tailed Ptarmigan             3
# Monk Parakeet                      3
# Common Nighthawk                   3
# Name: English_name, dtype: int64

# %%
X=good_boi1['English_name'].value_counts()[0:40]

# %%
L=X.index

# %%
len(X)
# Out:
# 40

# %%
for x in range(0,40):    
    if x==0:
        filter_boy=good_boi1[good_boi1['English_name']==L[x]]
    else:
        filter_boy=filter_boy.append(good_boi1[good_boi1['English_name']==L[x]],ignore_index=True)

# %%
len(filter_boy)
# Out:
# 8543

# %%
names=filter_boy.English_name

# %%
X=filter_boy.loc[:,['meanfreq','sd', 'freq.median', 'freq.Q25', 'freq.Q75', 'freq.IQR','sp.ent','entropy', 'sfm', 'meandom', 'mindom', 'maxdom','dfrange', 'modindx', 'startdom', 'enddom', 'dfslope', 'meanpeakf']]
Y=filter_boy['English_name']

# %%
y = Y.astype("category").cat.codes

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, stratify=y)

# %% [markdown]
# ## For Original Data

# %% [markdown]
# ### Linear regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.08023284292134614

# %% [markdown]
# ### K- nearest neighbours

# %%
knn=5
knn = KNeighborsClassifier(n_neighbors=knn)
knn.fit(X_train, y_train)
scores= knn.score(X_test, y_test)
print(scores)
# Out:
# 0.41591884510339444

# %%
from sklearn.neighbors import KNeighborsClassifier 
import matplotlib.pyplot as plt
scores = {}

for k in range(1,30):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    scores[k] = knn.score(X_test, y_test)

plt.plot([float(y_tt) for y_tt in scores.keys()], [float(x_tt) for x_tt in scores.values()])
plt.xlabel('k')
plt.ylabel('score')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn import metrics
predicted = knn.predict(X_test)
print(metrics.classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.66      0.64        95
#            1       0.55      0.40      0.47        77
#            2       0.42      0.38      0.40        79
#            3       0.71      0.85      0.77        87
#            4       0.65      0.59      0.62        82
#            5       0.54      0.78      0.64       116
#            6       0.60      0.63      0.61       132
#            7       0.54      0.56      0.55       225
#            8       0.48      0.33      0.39        88
#            9       0.64      0.47      0.54       102
#
#    micro avg       0.57      0.57      0.57      1083
#    macro avg       0.57      0.57      0.56      1083
# weighted avg       0.57      0.57      0.57      1083

# %%
print(metrics.confusion_matrix(y_test, predicted))
# Out:
# [[ 63   0   1  13   1   0   9   1   2   5]
#  [  1  31   4   0   3   9   2  22   5   0]
#  [  1   8  30   0   1   8   1  27   3   0]
#  [  4   0   0  74   1   0   6   0   0   2]
#  [  0   3   2   1  48   1   1  25   0   1]
#  [  0   1  10   0   0  91   8   2   4   0]
#  [ 10   1   2   8   1  11  83   5   4   7]
#  [  9  10  21   1  13  21  10 125   8   7]
#  [  3   0   1   2   2  23  10  13  29   5]
#  [ 12   2   1   5   4   6   9  10   5  48]]

# %%
import numpy as np
from sklearn import preprocessing
XX=preprocessing.normalize(X,axis=0)

# %%
XX
# Out:
# array([[ 0.01249668,  0.00688652,  0.01273455, ...,  0.01035764,
#         -0.0258992 ,  0.01111347],
#        [ 0.0125164 ,  0.00663834,  0.01253036, ...,  0.01035764,
#         -0.02722022,  0.01190329],
#        [ 0.01338626,  0.00659532,  0.01443288, ...,  0.01071075,
#         -0.02833395,  0.01698071],
#        ...,
#        [ 0.01103595,  0.01584448,  0.00907553, ...,  0.00918064,
#         -0.00141155,  0.0090825 ],
#        [ 0.01108513,  0.01613191,  0.00905275, ...,  0.00929834,
#         -0.00107881,  0.0090825 ],
#        [ 0.01108231,  0.01612812,  0.00905582, ...,  0.00929834,
#         -0.0010777 ,  0.0090825 ]])

# %%
Xx_train, Xx_test, yx_train, yx_test = train_test_split(XX,y,test_size = 0.3, stratify=y)

# %%
from sklearn.svm import SVC
model = SVC(kernel="linear",gamma=1,C=4)
model.fit(Xx_train, yx_train)
print(model.score(Xx_test, yx_test))
# Out:
# 0.08778774873195475

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn=1
knn = KNeighborsClassifier(n_neighbors=knn)
knn.fit(Xx_train, yx_train)
scores= knn.score(Xx_test, yx_test)
print(scores)
# Out:
# 0.428377153218495

# %%
from sklearn.svm import SVC
model = SVC(kernel="poly",degree=2,gamma=0.4, C=1)
model.fit(X_train, y_train)
print(model.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-179-008b476c1dde> in <module>
#       1 from sklearn.svm import SVC
#       2 model = SVC(kernel="poly",degree=2,gamma=0.4, C=1)
# ----> 3 model.fit(X_train, y_train)
#       4 print(model.score(X_test, y_test))
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     210
#     211         seed = rnd.randint(np.iinfo('i').max)
# --> 212         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     213         # see comment on the other call to np.iinfo in this file
#     214
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     269                 cache_size=self.cache_size, coef0=self.coef0,
#     270                 gamma=self._gamma, epsilon=self.epsilon,
# --> 271                 max_iter=self.max_iter, random_seed=random_seed)
#     272
#     273         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
from sklearn.svm import SVC
model = SVC(gamma=0.08, C=10)
model.fit(X_train, y_train)
print(model.score(X_test, y_test))
# Out:
# 0.5408878504672897

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(min_samples_split=2)
model.fit(Xx_train, yx_train)
print(model.score(Xx_test, yx_test))
# Out:
# 0.43737807257120564

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='newton-cg', max_iter=10000)
model.fit(X_train, y_train)
print(model.score(X_test, y_test))
# Out:
# /home/dan/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.30823253999219663

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
model = RandomForestClassifier(min_samples_split=2,n_estimators=500, max_features=3)
model.fit(Xx_train, yx_train)
print(model.score(Xx_test, yx_test))
# Out:
# 0.6429964884900508

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
modelada = RandomForestClassifier(max_depth=100, n_estimators=100, max_features=10)
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(base_estimator=modelada,n_estimators=500, random_state=0,learning_rate=1.5)
clf.fit(X_train,y_train)
print(clf.score(X_test,y_test))
# Out:
# 0.6168552477565353

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
kernel = 1.0 * RBF(1.0)
gpc = GaussianProcessClassifier(kernel=kernel,random_state=0).fit(Xx_train, yx_train)
gpc.score(Xx_test, yx_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-188-32ee829304ac> in <module>
#       2 from sklearn.gaussian_process.kernels import RBF
#       3 kernel = 1.0 * RBF(1.0)
# ----> 4 gpc = GaussianProcessClassifier(kernel=kernel,random_state=0).fit(Xx_train, yx_train)
#       5 gpc.score(Xx_test, yx_test)
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in fit(self, X, y)
#     632                                  % self.multi_class)
#     633
# --> 634         self.base_estimator_.fit(X, y)
#     635
#     636         if self.n_classes_ > 2:
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/multiclass.py in fit(self, X, y)
#     213                 "not %s" % self.label_binarizer_.classes_[i],
#     214                 self.label_binarizer_.classes_[i]])
# --> 215             for i, column in enumerate(columns))
#     216
#     217         return self
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     915             # remaining jobs.
#     916             self._iterating = False
# --> 917             if self.dispatch_one_batch(iterator):
#     918                 self._iterating = self._original_iterator is not None
#     919
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/multiclass.py in _fit_binary(estimator, X, y, classes)
#      78     else:
#      79         estimator = clone(estimator)
# ---> 80         estimator.fit(X, y)
#      81     return estimator
#      82
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in fit(self, X, y)
#     210             optima = [self._constrained_optimization(obj_func,
#     211                                                      self.kernel_.theta,
# --> 212                                                      self.kernel_.bounds)]
#     213
#     214             # Additional runs are performed from log-uniform chosen initial
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in _constrained_optimization(self, obj_func, initial_theta, bounds)
#     428         if self.optimizer == "fmin_l_bfgs_b":
#     429             theta_opt, func_min, convergence_dict = \
# --> 430                 fmin_l_bfgs_b(obj_func, initial_theta, bounds=bounds)
#     431             if convergence_dict["warnflag"] != 0:
#     432                 warnings.warn("fmin_l_bfgs_b terminated abnormally with the "
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     283     else:
#     284         def func_and_grad(x):
# --> 285             f = fun(x, *args)
#     286             g = jac(x, *args)
#     287             return f, g
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      61     def __call__(self, x, *args):
#      62         self.x = numpy.asarray(x).copy()
# ---> 63         fg = self.fun(x, *args)
#      64         self.jac = fg[1]
#      65         return fg[0]
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in obj_func(theta, eval_gradient)
#     202                 if eval_gradient:
#     203                     lml, grad = self.log_marginal_likelihood(
# --> 204                         theta, eval_gradient=True)
#     205                     return -lml, -grad
#     206                 else:
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in log_marginal_likelihood(self, theta, eval_gradient)
#     346         # which can be reused for computing Z's gradient
#     347         Z, (pi, W_sr, L, b, a) = \
# --> 348             self._posterior_mode(K, return_temporaries=True)
#     349
#     350         if not eval_gradient:
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in _posterior_mode(self, K, return_temporaries)
#     399             W_sr_K = W_sr[:, np.newaxis] * K
#     400             B = np.eye(W.shape[0]) + W_sr_K * W_sr
# --> 401             L = cholesky(B, lower=True)
#     402             # Line 6
#     403             b = W * f + (self.y_train_ - pi)
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      89     """
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#      93
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      35     overwrite_a = overwrite_a or _datacopied(a1, a)
#      36     potrf, = get_lapack_funcs(('potrf',), (a1,))
# ---> 37     c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
#      38     if info > 0:
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
#
# KeyboardInterrupt:

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
model = OneVsRestClassifier(SVC(kernel='linear')).fit(X_train, y_train)
print(model.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-267-7bbf4b77a077> in <module>
#       1 from sklearn.multiclass import OneVsRestClassifier
#       2 from sklearn.svm import SVC
# ----> 3 model = OneVsRestClassifier(SVC(kernel='linear')).fit(X_train, y_train)
#       4 print(model.score(X_test, y_test))
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/multiclass.py in fit(self, X, y)
#     213                 "not %s" % self.label_binarizer_.classes_[i],
#     214                 self.label_binarizer_.classes_[i]])
# --> 215             for i, column in enumerate(columns))
#     216
#     217         return self
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/multiclass.py in _fit_binary(estimator, X, y, classes)
#      78     else:
#      79         estimator = clone(estimator)
# ---> 80         estimator.fit(X, y)
#      81     return estimator
#      82
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     210
#     211         seed = rnd.randint(np.iinfo('i').max)
# --> 212         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     213         # see comment on the other call to np.iinfo in this file
#     214
#
# ~/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     269                 cache_size=self.cache_size, coef0=self.coef0,
#     270                 gamma=self._gamma, epsilon=self.epsilon,
# --> 271                 max_iter=self.max_iter, random_seed=random_seed)
#     272
#     273         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
model = OneVsRestClassifier(SVC(kernel='poly')).fit(X_train, y_train)
print(model.score(X_test, y_test))
# Out:
# /home/dan/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/dan/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn.multiclass import OneVsOneClassifier
from sklearn.svm import SVC
model = OneVsOneClassifier(SVC(kernel='rbf',gamma='auto')).fit(Xx_train, yx_train)
print(model.score(Xx_test, yx_test))
# Out:
# 0.05258386219401632

# %%
from sklearn.multiclass import OneVsOneClassifier
from sklearn.svm import SVC
model = OneVsOneClassifier(SVC(kernel='linear',gamma='auto')).fit(Xx_train, yx_train)
print(model.score(Xx_test, yx_test))
# Out:
# 0.05258386219401632

# %%
var=np.var(X,axis=0)
var
# Out:
# meanfreq          0.940415
# sd                0.299056
# freq.median       1.324306
# freq.Q25          0.842573
# freq.Q75          2.778496
# freq.IQR          2.104349
# skew             15.222455
# kurt           7202.059486
# sp.ent            0.009857
# time.ent          0.000450
# entropy           0.008998
# sfm               0.030360
# meandom           1.417921
# mindom            1.202714
# maxdom            2.849265
# dfrange           2.225645
# modindx           1.037679
# startdom          1.776609
# enddom            1.804933
# dfslope          67.840383
# meanpeakf         1.847416
# dtype: float64

# %%
import numpy as np
mean_bird = np.mean(X, axis=0)
mean_bird
# Out:
# meanfreq        3.732862
# sd              1.946468
# freq.median     3.211067
# freq.Q25        2.573352
# freq.Q75        4.244285
# freq.IQR        1.670932
# skew            6.329088
# kurt           68.287240
# sp.ent          0.811297
# time.ent        0.939716
# entropy         0.762342
# sfm             0.331584
# meandom         2.862249
# mindom          2.280243
# maxdom          3.559410
# dfrange         1.279166
# modindx         2.186181
# startdom        2.726660
# enddom          2.796137
# dfslope         0.481046
# meanpeakf       2.765378
# dtype: float64

# %% [markdown]
# ## We are doing SVD and only keeping dominant vectors

# %% [markdown]
#  import numpy as np
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
#
# clf=LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,solver='svd', store_covariance=False, tol=0.0001)
# #clf = LinearDiscriminantAnalysis()
# clf.fit(X_train,y_train)
# print(clf.score(X_test,y_test))

# %%
import numpy as np
from sklearn import preprocessing
XX=preprocessing.normalize(X,axis=0)
U, s, V = np.linalg.svd(XX)

# %%
s
# Out:
# array([3.96783201e+00, 9.87151099e-01, 7.16901440e-01, 5.66047442e-01,
#        4.50822159e-01, 3.46929696e-01, 2.58037200e-01, 1.43633817e-01,
#        1.30280889e-01, 1.01971385e-01, 5.97408418e-02, 4.83686679e-02,
#        4.40725432e-02, 2.65825105e-02, 2.27600739e-02, 1.49305849e-02,
#        7.43654014e-16, 1.53656754e-16])

# %%
plt.plot(s)
plt.show()

# %%
s[3:] = 0
S = np.zeros(X.shape)
S[:len(s), :len(s)] = np.diag(s)
US = np.matmul(U,S)
Xp = np.matmul(np.matmul(U,S),V)

# %%
US.shape
# Out:
# (8543, 18)

# %%
# %matplotlib notebook
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(US[:,0],US[:,1],US[:,2], c=y )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Xp_train, Xp_test, yp_train, yp_test = train_test_split(US[:,[0,1,2]],y, test_size = 0.3, stratify=y)

# %%
from sklearn.multiclass import OneVsOneClassifier
from sklearn.svm import SVC
model = OneVsOneClassifier(SVC(kernel='linear',gamma='auto')).fit(Xp_train, yp_train)
print(model.score(Xp_test, yp_test))
# Out:
# 0.05258386219401632

# %%
from sklearn.multiclass import OneVsOneClassifier
from sklearn.svm import SVC
model = OneVsOneClassifier(SVC(kernel='poly',gamma='auto')).fit(Xp_train, yp_train)
print(model.score(Xp_test, yp_test))
# Out:
# 0.05258386219401632

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
model = OneVsRestClassifier(SVC(kernel='linear',gamma='auto')).fit(Xp_train, yp_train)
print(model.score(Xp_test, yp_test))
# Out:
# 0.048504079782411606

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
model = OneVsRestClassifier(SVC(kernel='poly',gamma='auto')).fit(Xp_train, yp_train)
print(model.score(Xp_test, yp_test))
# Out:
# 0.034904805077062555

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(Xp_train,yp_train)
model.score(Xp_test,yp_test)
# Out:
# 0.08472475368725885

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(Xp_train, yp_train)
print(knn.score(Xp_test, yp_test))
# Out:
# 0.32230281051677245

# %%
from sklearn.svm import SVC
model = SVC(kernel="linear", C=0.025)
model.fit(Xp_train, yp_train)
print(model.score(Xp_test, yp_test))
# Out:
# 0.05258386219401632

# %%
from sklearn.svm import SVC
model = SVC(gamma=0.05, C=5)
model.fit(Xp_train, yp_train)
print(model.score(Xp_test, yp_test))
# Out:
# 0.05258386219401632

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=500)
model.fit(Xp_train, yp_train)
print(model.score(Xp_test, yp_test))
# Out:
# 0.26835902085222124

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', max_iter=10000)
model.fit(Xp_train, yp_train)
print(model.score(Xp_test, yp_test))
# Out:
# /home/dan/miniconda3/envs/hic-param-est/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.10335195530726257

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
model = RandomForestClassifier(max_depth=500, n_estimators=100, max_features=3)
model.fit(Xp_train, yp_train)
print(model.score(Xp_test, yp_test))
# Out:
# 0.33952855847688124

# %%
scores = {}

for k in range(1,20):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    scores[k] = knn.score(X_test, y_test)

plt.plot([float(y) for y in scores.keys()], [float(x) for x in scores.values()])
plt.xlabel('k')
plt.ylabel('score')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
